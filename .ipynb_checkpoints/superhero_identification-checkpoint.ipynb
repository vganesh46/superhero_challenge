# %%
import pandas as pd
import numpy as np
from PIL import Image
import cv2

from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.applications.imagenet_utils import preprocess_input
from keras.preprocessing import image
from matplotlib.pyplot import imshow
from keras.utils import to_categorical

from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions

from keras.applications.inception_v3 import InceptionV3

# %matplotlib inline

# %%
# import tensorflow as tf
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
import glob
ant_man = glob.glob('CAX_Superhero_Train/Ant-Man/*')
aqua_man = glob.glob('CAX_Superhero_Train/Aquaman/*')
avengers = glob.glob('CAX_Superhero_Train/Avengers/*')
bat_man = glob.glob('CAX_Superhero_Train/Batman/*')
black_panther = glob.glob('CAX_Superhero_Train/Black Panther/*')
captain_america = glob.glob('CAX_Superhero_Train/Captain America/*')
cat_woman = glob.glob('CAX_Superhero_Train/Catwoman/*')
ghostrider = glob.glob('CAX_Superhero_Train/Ghost Rider/*')
hulk = glob.glob('CAX_Superhero_Train/Hulk/*')
iron_man = glob.glob('CAX_Superhero_Train/Iron Man/*')
spider_man = glob.glob('CAX_Superhero_Train/Spiderman/*')
super_man = glob.glob('CAX_Superhero_Train/Superman/*')

# %% [markdown]
# Images are of different sizes. I'm defining an upper limit of (224,224,3) and cropping images above this size and padding images smaller than this size.

# %%
def img_to_array(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

# %%
### START CODE HERE ###
img_path = 'CAX_Superhero_Test/superhero_test_100.jpg'
img = image.load_img(img_path, target_size=(224, 224))
imshow(img)

# %%
# def img_to_label(img_path):
#     y = img_path.split("cax_",1)[1].split("_train",1)[0]
#     return y

# %%
x1 = np.concatenate([img_to_array(img_path) for img_path in ant_man])
x2 = np.concatenate([img_to_array(img_path) for img_path in aqua_man])
x3 = np.concatenate([img_to_array(img_path) for img_path in avengers])
x4 = np.concatenate([img_to_array(img_path) for img_path in bat_man])
x5 = np.concatenate([img_to_array(img_path) for img_path in black_panther])
x6 = np.concatenate([img_to_array(img_path) for img_path in captain_america])
x7 = np.concatenate([img_to_array(img_path) for img_path in cat_woman])
x8 = np.concatenate([img_to_array(img_path) for img_path in ghostrider])
x9 = np.concatenate([img_to_array(img_path) for img_path in hulk])
x10 = np.concatenate([img_to_array(img_path) for img_path in iron_man])
x11 = np.concatenate([img_to_array(img_path) for img_path in spider_man])
x12 = np.concatenate([img_to_array(img_path) for img_path in super_man])

# %%
y1 = ['ant_man' for img_path in ant_man]
y2 = ['aqua_man' for img_path in aqua_man]
y3 = ['avengers' for img_path in avengers]
y4 = ['bat_man' for img_path in bat_man]
y5 = ['black_panther' for img_path in black_panther]
y6 = ['captain_america' for img_path in captain_america]
y7 = ['cat_woman' for img_path in cat_woman]
y8 = ['ghostrider' for img_path in ghostrider]
y9 = ['hulk' for img_path in hulk]
y10 = ['iron_man' for img_path in iron_man]
y11 = ['spider_man' for img_path in spider_man]
y12 = ['super_man' for img_path in super_man]

# %%
x = np.vstack([x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12])

# %%
y = np.concatenate([y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12])

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

le = LabelEncoder()
le1 = le.fit_transform(y) 


# convert integers to dummy variables (i.e. one hot encoded)
y = to_categorical(le1)

# %%
from sklearn import preprocessing
from sklearn import model_selection

def model_feed(x,y):
    x_train, x_validate, y_train, y_validate = model_selection.train_test_split(x, y, test_size=0.2, shuffle=True)
    
    return (x_train,y_train,x_validate,y_validate)

# %%
x_train,y_train,x_validate,y_validate = model_feed(x,y)

# %% [markdown]
# ## 1) CNN

# %%
def Basic_CNN(input_shape):

    X_input = Input(input_shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    
    X = Conv2D(32, (7, 7), strides=(1, 1), name='conv0')(X)
    X = BatchNormalization(axis=3, name='bn0')(X)
    X = Activation('relu')(X)

    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool')(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    
    X = Flatten()(X)
    X = Dense(12, activation='softmax', name='fc')(X)

    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X)
    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = Basic_CNN(x_train.shape[1:])

model.fit(x_train, y_train, validation_data=(x_validate, y_validate), epochs=10, batch_size= 50, verbose=2)
# Out:
# Train on 4346 samples, validate on 1087 samples
# Epoch 1/10
#  - 21s - loss: 13.3770 - acc: 0.1624 - val_loss: 13.7901 - val_acc: 0.1444
# Epoch 2/10
#  - 12s - loss: 13.5072 - acc: 0.1620 - val_loss: 13.7901 - val_acc: 0.1444
# Epoch 3/10
#  - 12s - loss: 13.5072 - acc: 0.1620 - val_loss: 13.7901 - val_acc: 0.1444
# Epoch 4/10
#  - 12s - loss: 13.5072 - acc: 0.1620 - val_loss: 13.7901 - val_acc: 0.1444
# Epoch 5/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-ed74c3217c96> in <module>()
#       1 model = Basic_CNN(x_train.shape[1:])
#       2
# ----> 3 model.fit(x_train, y_train, validation_data=(x_validate, y_validate), epochs=10, batch_size= 50, verbose=2)
#
# ...

# %% [markdown]
# ## 2) ResNet

# %%
resnetbasemodel = ResNet50(include_top=True, weights='imagenet')

# %%
def ResNet_v1():

    x = resnetbasemodel.output
    x = Dense(1024, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    predictions = Dense(12, activation='softmax')(x)

    model = Model(inputs=resnetbasemodel.input, outputs=predictions)

    for layer in resnetbasemodel.layers:
        layer.trainable = False

    model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
model = ResNet_v1()

model.fit(x_train, y_train, validation_data=(x_validate, y_validate), epochs=10, batch_size= 50, verbose=2)
# Out:
# Train on 4346 samples, validate on 1087 samples
# Epoch 1/10
#  - 36s - loss: 2.3171 - acc: 0.2011 - val_loss: 2.3005 - val_acc: 0.1684
# Epoch 2/10
#  - 28s - loss: 2.0793 - acc: 0.3426 - val_loss: 2.3162 - val_acc: 0.1858
# Epoch 3/10
#  - 28s - loss: 1.8348 - acc: 0.4220 - val_loss: 2.4974 - val_acc: 0.1610
# Epoch 4/10
#  - 28s - loss: 1.6508 - acc: 0.4779 - val_loss: 2.6441 - val_acc: 0.1592
# Epoch 5/10
#  - 28s - loss: 1.5135 - acc: 0.5110 - val_loss: 2.7985 - val_acc: 0.1564
# Epoch 6/10
#  - 28s - loss: 1.4106 - acc: 0.5513 - val_loss: 2.8339 - val_acc: 0.1500
# Epoch 7/10
#  - 28s - loss: 1.3271 - acc: 0.5794 - val_loss: 2.7776 - val_acc: 0.1601
# Epoch 8/10
#  - 28s - loss: 1.2564 - acc: 0.5971 - val_loss: 2.8695 - val_acc: 0.1656
# Epoch 9/10
#  - 28s - loss: 1.1919 - acc: 0.6190 - val_loss: 2.9282 - val_acc: 0.1730
# Epoch 10/10
#  - 28s - loss: 1.1313 - acc: 0.6353 - val_loss: 2.8529 - val_acc: 0.1739

# %% [markdown]
# ### Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# data generator
def create_datagen():
  datagen = ImageDataGenerator(
    featurewise_center=True, # Set input mean to 0 over the dataset, feature-wise
    featurewise_std_normalization=True, # Divide inputs by std of the dataset, feature-wise
    zca_whitening=True, # Apply ZCA whitening
    rotation_range=20, # Degree range for random rotations
    width_shift_range=0.2, # Range for random horizontal shifts
    height_shift_range=0.2, # Range for random vertical shifts
    shear_range=0.2, # hear Intensity (Shear angle in counter-clockwise direction as radians)
    zoom_range=0.2, # Range for random zoom. If a float
    channel_shift_range=0.2, # Range for random channel shifts
    fill_mode='nearest', # Points outside the boundaries of the input are filled according to the given mode
    horizontal_flip=True, # Randomly flip inputs horizontally
    vertical_flip=True, # Randomly flip inputs vertically
  )
  return datagen

# instantiate a data generator
datagen = create_datagen()
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/keras/preprocessing/image.py:519: UserWarning: This ImageDataGenerator specifies `zca_whitening` which overrides setting of`featurewise_std_normalization`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
model = ResNet_v1() # initialize model

model.fit_generator(datagen.flow(x_train, y_train),samples_per_epoch=len(x_train) * 5, nb_epoch = 10) # augment data by a factor of 5
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., steps_per_epoch=679, epochs=10)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/10
# ...

# %% [markdown]
# ### Sample check

# %%
img_path = 'CAX_Superhero_Test/superhero_test_300.jpg'
img = image.load_img(img_path, target_size=(224, 224))
imshow(img)

x_sample = img_to_array(img_path)

y_sample = np.argmax(model.predict(x_sample),axis = 1)

y_sample1 = le.inverse_transform(y_sample)

print (y_sample1)
# Out:
# ['captain_america']
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# ###### Submission

# %%
testpath = glob.glob('CAX_Superhero_Test/*')
x_test = np.concatenate([img_to_array(img_path) for img_path in testpath])

y_test = np.argmax(model.predict(x_test),axis=1)
y_test1 = le.inverse_transform(y_test)

df = pd.DataFrame.from_csv('Superhero_3375_SampleSubmission.csv')

list1 = list(df.index)
list2 = list(y_test1)
df1 = pd.DataFrame(np.column_stack([list1,list2]),columns = ['filename','Superhero'])
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   import sys

# %%
df1.to_csv('submissionresnet.csv')
